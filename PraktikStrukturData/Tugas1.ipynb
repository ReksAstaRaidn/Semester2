# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# %%
class LinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        current = self.head
        while current.next:
            current = current.next
        current.next = new_node

    def jumlahList(self):
        total = 0
        current = self.head
        while current:
            total += current.data
            current = current.next
        return total

# %%
jmlh = LinkedList()
for val in [5, 6, 3, 1]:
    jmlh.append(val)
    
print(f"Jumlah data list: {jmlh.jumlahList()}")
# Out:
# Jumlah data list: 15

# %% [markdown]
# # Pembahasan #

# %% [raw]
# Program ini mendemostrasikan linked list sederhana serta menghitung total jumlah nilai yang ada didalamnya
#
# Class
# Node adalah sebuah fondasi dari linked list yang dimana setiap data (node) menyimpan nilai (self.data) dan pointer ke data berikutntya (self.next)
#
# LinkedList class ini berisi beberapa method untuk mengelola susunan data
#
# Method
# append(data) method ini berfungsi untuk menambahkan data baru diakhir list
#
# jumlahList method ini adalah method yang berfungsi untuk menjumlahkan nilai yang ada didalam linked list, yang dimana method ini akan melakukan loop dari awal hingga akhir list lalu mengambil data nya dan dijumlahkan
