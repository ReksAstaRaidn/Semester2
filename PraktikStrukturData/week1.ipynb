# %% [markdown]
# Meiza Reksa Fahrevi

# %%
##Teknologi Informasi

# %%
print('Hello World')
# Out:
# Hello World

# %%
tinggi = 165
berat = 57

# %%
tinggi
# Out:
# 165

# %%
berat
# Out:
# 57

# %% [markdown]
# Menghitung BMI

# %%
tinggi = 1.78 #meter
berat = 70 #KG

# %%
70 / 1.78 ** 2
# Out:
# 22.093170054286073

# %%
berat / tinggi ** 2
# Out:
# 22.093170054286073

# %%
bmi = berat / tinggi ** 2

# %%
bmi
# Out:
# 22.093170054286073

# %%
tinggi = 1.80
berat = 70
bmi = berat / tinggi ** 2
print (bmi)
# Out:
# 21.604938271604937

# %% [markdown]
# Data Types

# %%
type (bmi)
# Out:
# float

# %%
jumlah_hari = 7

# %%
type (jumlah_hari)
# Out:
# int

# %%
x = 'BMI itu apa?'
y = 'Haha'

# %%
print(type(x), type(y))
# Out:
# <class 'str'> <class 'str'>

# %%
type(x)
# Out:
# str

# %%
type(y)
# Out:
# str

# %%
z = True 
type(z)
# Out:
# bool
