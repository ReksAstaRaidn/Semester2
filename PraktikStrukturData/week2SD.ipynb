# %% [markdown]
# # Operator Rasional #

# %%
a = int(input("masukkan a = "))
b = int(input("masukkan b = "))
c = int(input("masukkan c = "))
d = int(input("masukkan d = "))

print("a==b", a==b)
print("a==c", a==c)
print("a!=b", a!=b)

print("a>d", a>d)
print("b<d", b<d)
print("b<=d", b<=d)
print("b>=d", b>=d)
# Out:
# masukkan a =  6
# masukkan b =  5
# masukkan c =  4
# masukkan d =  3
# a==b False
# a==c False
# a!=b True
# a>d True
# b<d False
# b<=d False
# b>=d True

# %% [markdown]
# # Operator Aritmatika #

# %%
x = 5 + 2 * 3 / (2 - 3) ** 2
print(x)
# Out:
# 11.0

# %%
x = 10
y = 3
print("x=",x)
print("y=",y)
print("x+y=", (x+y))
# Out:
# x= 10
# y= 3
# x+y= 13

# %%
print("x-y=", (x-y))
print("x*y=", (x*y))
print("x/y=", (x/y))
print("x//y=", (x//y))
print("x%y=", (x%y))
print("x**y=", (x**y))
# Out:
# x-y= 7
# x*y= 30
# x/y= 3.3333333333333335
# x//y= 3
# x%y= 1
# x**y= 1000

# %% [markdown]
# # Struktur Pemilihan #

# %%
a = 5
b = 5

if a==b:
    print("a dan b bernilai sama")
else:
    print("a dan b bernilai berbeda")
    print("Halo")
# Out:
# a dan b bernilai sama

# %%
# read two numbers
number1 = int(input("Enter the first number: "))
number2 = int(input("Enter the second number: "))
# choose the larger number
if number1 > number2:
    largerNumber = number1
else:
    largerNumber = number2
    
# print the result
print("The larger number is:", largerNumber)
# Out:
# Enter the first number:  6
# Enter the second number:  3
# The larger number is: 6

# %% [markdown]
# # Latihan 1 #

# %%
bilangan = int(input("Masukkan bilangan bulat:"))

if bilangan %2 == 0:
    print(str (bilangan) + " Adalah Bilangan Genap")
else:
    print(str (bilangan) + " Adalah Bilangan Ganjil")
# Out:
# Masukkan bilangan bulat: 6
# 6 Adalah Bilangan Genap

# %% [markdown]
# # Latihan 2 #

# %%
def main():
    print("Memasukkan nilai koordinat")
    x = int(input("Masukkan nilai x"))
    y = int(input("Masukkan nilai y"))

    if x > 0 and y > 0:
        print("Koordinat ("+ str(x) + "," + str(y) +") berada pada kuardran " + "I")
    elif x<0 and y>0 :
        print("Koordinat ("+ str(x) + "," + str(y) +") berada pada kuardran " + "II")
    elif x<0 and y<0 :
        print("Koordinat ("+ str(x) + "," + str(y) +") berada pada kuardran " + "III")
    elif x>0 and y<0 :
        print("Koordinat ("+ str(x) + "," + str(y) +") berada pada kuardran " + "IV")
    else :
        pass
        
main()
# Out:
# Memasukkan nilai koordinat
# Masukkan nilai x 1
# Masukkan nilai y -1
# Koordinat (1,-1) berada pada kuardran IV

# %% [markdown]
# # Latihan 3 Cari Bilangan Terbesar #

# %%
number1 = int(input("Enter the first number: "))
number2 = int(input("Enter the Second number: "))
number3 = int(input("Enter the third number: "))

#anggap angka pertama paling besar 

largestNumber =  number1

#untuk mengecek apakah nomor kedua lebih besar, jika lebih besar, largestNumber diupdate
if number2 > largestNumber:
    largestNumber = number2

if number3 > largestNumber:
    largestNumber = number3

print("the largest number is: ", largestNumber)
# Out:
# Enter the first number:  4
# Enter the Second number:  5
# Enter the third number:  9
# the largest number is:  9

# %% [markdown]
# # Spathiphyllum #

# %%
plant = input("Please input the best plant: ")

if plant == "Spathiphyllum":
    print("Yes, Spathiphyllum is the best plant")
elif plant == "spathiphyllum":
    print("No, i want a big Spathiphyllum")
else:
    print("Spathiphyllum! not " + plant)
# Out:
# Please input the best plant:  spathiphyllum
# No, i want a big Spathiphyllum

# %% [markdown]
# # Tax Calculator #

# %%
pemasukan = float(input("Masukkan penghasilan: "))

thaler = 85528

if pemasukan < thaler:
    tax = pemasukan * 0.18 - 556 + 0.02 
else:
    tax =   14839 + 0.02 + ((pemasukan - thaler) * 0.32)

if tax < 0:
    tax = 0.0

taxRound = round(tax, 0)
print("the tax is: ", taxRound, " thalers")
# Out:
# Masukkan penghasilan:  100000
# the tax is:  19470.0  thalers

# %%
year = int(input("Enter a year: "))
gregorianCalen = 1582

if year < 1582:
    print("not wihtin Gregorian Calender")
else:
    if year % 4 != 0:
        print("common year")
    elif year % 100 != 0:
        print("leap year")
    elif year % 400 != 0:
        print("common year")
    else:
        print("leap year ")
# Out:
# Enter a year:  2007
# common year

# %% [markdown]
# # Latihan 3 #

# %%
x = 5
y = 10
z = 8

print(x > y)
print(y > z)
# Out:
# False
# True

# %%
x, y, z = 5, 10, 8

print(x > z)
print((y - 5) == x)
# Out:
# False
# True

# %%
x, y, z = 5, 10, 8
x, y, z = z, y, x

print(x > z)
print((y - 5) == x)
# Out:
# True
# False

# %%
x = 10
if x == 10:
    print(x == 10)
    
if x > 5:
    print(x > 5)
    
if x < 10:
    print(x < 10)
else:
    print("else")
# Out:
# True
# True
# else

# %%
x = "1"

if x == 1:
    print("one")
elif x == "1":
    if int(x) > 1:
        print("two")
    elif int(x) < 1:
        print("three")
    else:
        print("four")
        
if int(x) == 1:
    print("five")
else:
    print("six")
# Out:
# four
# five

# %%
x = 1
y = 1.0
z = "1"

if x == y:
    print("one")
    
if y == int(z):
    print("two")
elif x == y:
    print("three")
else:
    print("four")
# Out:
# one
# two

# %% [markdown]
# # Struktur Perulangan #

# %% [markdown]
# While

# %%
# we will store the current largest number here
largestNumber = -999999999

# input the first value
number = int(input("Enter a number or type -1 to stop: "))

# if the number is not equal to -1, we will continue
while number != -1:
    # is number larger than largestNumber?
    if number > largestNumber:
    # yes, update largestNumber
        largestNumber = number
        
    # input the next number
    number = int(input("Enter a number or type -1 to stop: "))

# print the largest number
print("The largest number is:", largestNumber)
# Out:
# Enter a number or type -1 to stop:  1
# Enter a number or type -1 to stop:  2
# Enter a number or type -1 to stop:  3
# Enter a number or type -1 to stop:  4
# Enter a number or type -1 to stop:  5
# Enter a number or type -1 to stop:  2
# Enter a number or type -1 to stop:  1
# Enter a number or type -1 to stop:  4
# Enter a number or type -1 to stop:  1
# Enter a number or type -1 to stop:  2
# Enter a number or type -1 to stop:  -1
# The largest number is: 5

# %%
oddNumbers = 0
evenNumbers = 0

number = int(input("Enter a number or type 0 to stop: "))

while number != 0:
    if number % 2 == 1:
        oddNumbers += 1
    else:
        evenNumbers += 1
    number = int(input("Enter a number or type 0 to stop: "))

print("Odd numbers count:", oddNumbers)
print("Even numbers count:", evenNumbers)
# Out:
# Enter a number or type 0 to stop:  4
# Enter a number or type 0 to stop:  35
# Enter a number or type 0 to stop:  76
# Enter a number or type 0 to stop:  98
# Enter a number or type 0 to stop:  23
# Enter a number or type 0 to stop:  0
# Odd numbers count: 2
# Even numbers count: 3

# %%
secretNumber = 777
print(
"""
+================================+
| Welcome to my game, muggle! |
| Enter an integer number |
| and guess what number I've |
| picked for you. |
| So, what is the secret number? |
+================================+
""")

guessNumber = 0

while guessNumber != secretNumber:
    guessNumber = int(input("So, what is the secret number? "))
    if guessNumber != secretNumber:
        print("Ha ha! You're stuck in my loop!")
print("Well done, muggle! You are free now.")
# Out:
# +================================+
# | Welcome to my game, muggle! |
# | Enter an integer number |
# | and guess what number I've |
# | picked for you. |
# | So, what is the secret number? |
# +================================+
# So, what is the secret number?  89
# Ha ha! You're stuck in my loop!
# So, what is the secret number?  23
# Ha ha! You're stuck in my loop!
# So, what is the secret number?  777
# Well done, muggle! You are free now.

# %% [markdown]
# # Statement loop #

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5):
    print(i)
else:
    print("Masuk Else")
# Out:
# 0
# 1
# 2
# 3
# 4
# Masuk Else

# %%
import time

for i in range(5):
    print(i, "Missisipi")
    time.sleep(1)
# Out:
# 0 Missisipi
# 1 Missisipi
# 2 Missisipi
# 3 Missisipi
# 4 Missisipi

# %% [markdown]
# # Break #

# %%
for i in range(11):
    print(i, end=' ')
    if i == 7:
        print("Masih dalam for")
        break
# Out:
# 0 1 2 3 4 5 6 7 Masih dalam for

# %%
# break - example
print("The break instruction:")
for i in range(1, 6):
    if i == 3:
        break
    print("Inside the loop.", i)
print("Outside the loop.")
# Out:
# The break instruction:
# Inside the loop. 1
# Inside the loop. 2
# Outside the loop.

# %%
largestNumber = -99999999
counter = 0

while True:
    number = int(input("Enter a number or type -1 to end program: "))
    if number == -1:
        break
        
    counter += 1
    if number > largestNumber:
        largestNumber = number
    
if counter != 0:
    print("The largest number is", largestNumber)
else:
    print("You haven't entered any number.")
# Out:
# Enter a number or type -1 to end program:  4
# Enter a number or type -1 to end program:  6
# Enter a number or type -1 to end program:  23
# Enter a number or type -1 to end program:  8
# Enter a number or type -1 to end program:  5
# Enter a number or type -1 to end program:  -1
# The largest number is 23

# %% [markdown]
# # Continue #

# %%
for i in range (1,11):
    if i % 2 ==0:
        continue
    print(i, end='\t')
# Out:
# 1	3	5	7	9

# %%
# continue - example
print("\nThe continue instruction:")
for i in range(1, 6):
    if i == 3:
        continue
    print("Inside the loop.", i)
print("Outside the loop.")
# Out:
# The continue instruction:
# Inside the loop. 1
# Inside the loop. 2
# Inside the loop. 4
# Inside the loop. 5
# Outside the loop.

# %%
largestNumber = -99999999
counter = 0

number = int(input("Enter a number or type -1 to end program: "))

while number != -1:
    if number == -1:
        continue
    counter += 1
    
    if number > largestNumber:
        largestNumber = number
    number = int(input("Enter a number or type -1 to end program: "))
if counter:
    print("The largest number is", largestNumber)
else:
    print("You haven't entered any number.")
# Out:
# Enter a number or type -1 to end program:  4
# Enter a number or type -1 to end program:  7
# Enter a number or type -1 to end program:  2
# Enter a number or type -1 to end program:  8
# Enter a number or type -1 to end program:  -1
# The largest number is 8

# %%
# Prompt the user to enter a word
# and assign it to the userWord variable.
userWord = input("Masukkan sebuah kata = ")

for letter in userWord:
    if letter.upper() in ['A','I','U','E','O']:
        continue
    print(letter.upper())
# Out:
# Masukkan sebuah kata =  gregory
# G
# R
# G
# R
# Y

# %%
lokasi = "Jum'at"

for a in lokasi:
    print(a.upper() + " +++ ")
# Out:
# J +++
# U +++
# M +++
# ' +++
# A +++
# T +++

# %%
wordWithoutVovels = ""
# Prompt the user to enter a word
# and assign it to the userWord variable.

userWord = input("Masukkan sebuah kata = ")

for letter in userWord:
    if letter.upper() in ['A','I','U','E','O']:
        continue
    wordWithoutVovels += letter.upper()
    print(wordWithoutVovels)
print(wordWithoutVovels)
# Out:
# Masukkan sebuah kata =  meiza reksa fahrevi
# M
# MZ
# MZ
# MZ R
# MZ RK
# MZ RKS
# MZ RKS
# MZ RKS F
# MZ RKS FH
# MZ RKS FHR
# MZ RKS FHRV
# MZ RKS FHRV

# %%
blocks = int(input("Enter the number of blocks: "))
current_block = 0
height = 0

while i<blocks:
    height += 1
    current_block += height
    # print(i,current_block)
    if current_block> blocks:
        break
height -= 1
print("The height of the pyramid:", height)
# Out:
# Enter the number of blocks:  6
# The height of the pyramid: 3

# %%
x = 1
y = 0
z = ((x == y) and (x == y)) or not(x == y)

print(not(z))
# Out:
# False
