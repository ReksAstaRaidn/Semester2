# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# %%
class LinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        current = self.head
        while current.next:
            current = current.next
        current.next = new_node
        
    def print_list(self):
        result = []
        current = self.head
        while current:
            result.append(str(current.data))
            current = current.next
        print(" -> ".join(result))

# %%
def reverse_k_group(self, k):
    def reverse_group(head, k):
        prev = None
        current = head
        count = 0
        # Balik sebanyak k node
        while current and count < k:
            next_node = current.next
            current.next = prev
            prev = current
            current = next_node
            count += 1
        # Sambungkan sisa list secara rekursif
        if current:
            head.next = reverse_group(current, k)
        return prev

    self.head = reverse_group(self.head, k)

# %%
LinkedList.reverse_k_group = reverse_k_group

isiList= LinkedList()
for val in [1, 2, 3, 4, 5, 6, 7, 8]:
    isiList.append(val)
    
isiList.reverse_k_group(3)
    
isiList.print_list()
# Out:
# 3 -> 2 -> 1 -> 6 -> 5 -> 4 -> 8 -> 7

# %% [markdown]
# # Pembahasan #

# %% [raw]
# Program ini mendemostrasikan pembalikan urutan dalam linked list tetapi dikelompokkan
#
# Class
# Node adalah sebuah fondasi dari linked list yang dimana setiap data (node) menyimpan nilai (self.data) dan pointer ke data berikutntya (self.next)
#
# LinkedList class ini berisi beberapa method untuk mengelola susunan data
#
# Method
# append(data) method ini berfungsi untuk menambahkan data baru diakhir list
#
# print_list method ini berfungsi untuk mencetak semua nilai data yang ada didalam list disambung dengan tanda panah
#
# reverse_k_group method ini berisi sebuah method reverse_group yang berfungsi untuk membalikkan suatu kelompok (k) dengan while loop seperti contoh nya program akan membalikkan 3 data, maka 3 data tersebut akan dibalikkan urutan nya lalu setelah satu kelompok selesai dibalik, method akan mengecek sisa data lainnya jika masih ada data yang tersisa maka method nya akan lanjut membalikkan kelompok data berikutnya
