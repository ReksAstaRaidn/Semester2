# %%
import sys
import collections

try:
    import graphviz
except ImportError:
    print("Graphviz library not found. Installing...")
    # !{sys.executable} -m pip install graphviz
    import graphviz

class Graph:
    def __init__(self, directed=False):
        self.graph = collections.defaultdict(list)
        self.directed = directed

    def add_edge(self, u, v):
        self.graph[u].append(v)
        if not self.directed:
            self.graph[v].append(u)

    def get_neighbors(self, u):
        return self.graph[u]

    def display(self):
        print("Adjacency List Graph Jawa Tengah:")
        for node in sorted(self.graph.keys()):
            print(f"  {node}: {sorted(self.graph[node])}")


jateng_graph = Graph(directed=False)

edges_jateng = [
    ('Brebes', 'Tegal'),
    ('Tegal', 'Pemalang'),
    ('Pemalang', 'Pekalongan'),
    ('Pekalongan', 'Kendal'),
    ('Kendal', 'Semarang'),
    ('Semarang', 'Demak'),
    ('Demak', 'Kudus'),
    ('Kudus', 'Rembang'),
    ('Rembang', 'Blora'),

    ('Tegal', 'Slawi'),
    ('Brebes', 'Slawi'),
    ('Slawi', 'Purwokerto'),
    ('Purwokerto', 'Purbalingga'),
    ('Purbalingga', 'Banjarnegara'),
    ('Banjarnegara', 'Wonosobo'),
    ('Wonosobo', 'Temanggung'),
    ('Temanggung', 'Magelang'),
    ('Magelang', 'Boyolali'),
    ('Pekalongan', 'Banjarnegara'),

    ('Blora', 'Purwodadi'),
    ('Blora', 'Sragen'),
    ('Purwodadi', 'Demak'),
    ('Purwodadi', 'Sragen'),
    ('Sragen', 'Solo'),
    ('Semarang', 'Salatiga'),
    ('Salatiga', 'Boyolali'),
    ('Boyolali', 'Solo'),
    ('Solo', 'Sukoharjo'),
    ('Solo', 'Klaten'),
    ('Sukoharjo', 'Klaten'),
    ('Klaten', 'Magelang'),
    
    ('Magelang', 'Purworejo'),
    ('Purworejo', 'Kebumen'),
    ('Kebumen', 'Banjarnegara'),
    ('Kebumen', 'Kroya'),
    ('Kroya', 'Purwokerto'),
    ('Kroya', 'Cilacap'),
    ('Cilacap', 'Purwokerto'),
    ('Purwokerto', 'Kebumen')
]

for u, v in edges_jateng:
    jateng_graph.add_edge(u, v)

# %%
def visualize_jateng(graph_obj, graph_name="Graph", highlight_path=None):
    """
    Visualizes the Jawa Tengah graph using Graphviz.

    Args:
        graph_obj (Graph): The graph object.
        graph_name (str): The name for the graph visualization.
        highlight_path (list): An optional list of nodes to highlight as a path.
    """
    dot = graphviz.Graph(comment=graph_name)
    dot.attr(rankdir='LR', size='14,10')
    dot.attr('graph', label=graph_name, fontsize='16', fontname='Helvetica')

    # Kumpulkan semua node
    nodes_in_graph = set()
    for u, neighbors in graph_obj.graph.items():
        nodes_in_graph.add(str(u))
        for v in neighbors:
            nodes_in_graph.add(str(v))

    # Tambahkan semua node
    for node in sorted(nodes_in_graph):
        dot.node(node, style='filled', fillcolor='lightblue',
                 fontname='Helvetica', shape='ellipse')

    # Tambahkan edge (hindari duplikat untuk undirected graph)
    added_edges = set()
    for u, neighbors in graph_obj.graph.items():
        for v in neighbors:
            if (str(v), str(u)) not in added_edges and (str(u), str(v)) not in added_edges:
                dot.edge(str(u), str(v))
                added_edges.add((str(u), str(v)))

    # Highlight path jika diberikan
    if highlight_path:
        for i in range(len(highlight_path)):
            node = str(highlight_path[i])
            dot.node(node, style='filled',
                     fillcolor='red' if i == 0 else 'lightgreen',
                     fontcolor='white' if i == 0 else 'black')
            if i < len(highlight_path) - 1:
                u = str(highlight_path[i])
                v = str(highlight_path[i + 1])
                dot.edge(u, v, color='red', penwidth='2.5')

    return dot


# Tampilkan graph Jawa Tengah
print("=== Visualisasi Graph Kota-Kota Jawa Tengah ===")
display(visualize_jateng(jateng_graph, graph_name="Peta Koneksi Kota Jawa Tengah"))
# Out:
# === Visualisasi Graph Kota-Kota Jawa Tengah ===
